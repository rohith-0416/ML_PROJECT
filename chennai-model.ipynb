# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
# %matplotlib inline 
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv(r"R:\Chennai houseing sale.csv")
df1
# Out:
#       PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0     P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1     P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2     P01812       Adyar       909  04-02-2012             70        1.0
# 3     P05346   Velachery      1855  13-03-2010             14        3.0
# 4     P06210  Karapakkam      1226  05-10-2009             84        1.0
# ...      ...         ...       ...         ...            ...        ...
# 7104  P03834  Karapakkam       598  03-01-2011             51        1.0
# 7105  P10000   Velachery      1897  08-04-2004             52        3.0
# 7106  P09594   Velachery      1614  25-08-2006            152        2.0
# 7107  P06508  Karapakkam       787  03-08-2009             40        1.0
# 7108  P09794   Velachery      1896  13-07-2005            156        3.0
#
#       N_BATHROOM  N_ROOM    SALE_COND PARK_FACIL  ... UTILITY_AVAIL  \
# 0            1.0       3     AbNormal        Yes  ...        AllPub
# 1            1.0       5     AbNormal         No  ...        AllPub
# 2            1.0       3     AbNormal        Yes  ...           ELO
# 3            2.0       5       Family         No  ...       NoSewr
# 4            1.0       3     AbNormal        Yes  ...        AllPub
# ...          ...     ...          ...        ...  ...           ...
# 7104         1.0       2      AdjLand         No  ...           ELO
# 7105         2.0       5       Family        Yes  ...        NoSeWa
# 7106         1.0       4  Normal Sale         No  ...        NoSeWa
# 7107         1.0       2      Partial        Yes  ...           ELO
# 7108         2.0       5      Partial        Yes  ...           ELO
#
#          STREET MZZONE QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  \
# 0         Paved      A      4.0         3.9         4.9       4.330   380000
# 1        Gravel     RH      4.9         4.2         2.5       3.765   760122
# 2        Gravel     RL      4.1         3.8         2.2       3.090   421094
# 3         Paved      I      4.7         3.9         3.6       4.010   356321
# 4        Gravel      C      3.0         2.5         4.1       3.290   237000
# ...         ...    ...      ...         ...         ...         ...      ...
# 7104  No Access     RM      3.0         2.2         2.4       2.520   208767
# 7105  No Access     RH      3.6         4.5         3.3       3.920   346191
# 7106     Gravel      I      4.3         4.2         2.9       3.840   317354
# 7107      Paved     RL      4.6         3.8         4.1       4.160   425350
# 7108      Paved      I      3.1         3.5         4.3       3.640   349177
#
#       COMMIS  SALES_PRICE
# 0     144400      7600000
# 1     304049     21717770
# 2      92114     13159200
# 3      77042      9630290
# 4      74063      7406250
# ...      ...          ...
# 7104  107060      5353000
# 7105  205551     10818480
# 7106  167028      8351410
# 7107  119098      8507000
# 7108   79812      9976480
#
# [7109 rows x 22 columns]

# %%
df1.shape
# Out:
# (7109, 22)

# %%
df1.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
df1['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
df1['AREA'].value_counts()
# Out:
# AREA
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: count, dtype: int64

# %%
df1['BUILDTYPE'].value_counts()
# Out:
# BUILDTYPE
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: count, dtype: int64

# %%
df2 = df1.drop(['PRT_ID', 'DIST_MAINROAD','SALE_COND', 'PARK_FACIL','COMMIS', 'UTILITY_AVAIL', 'STREET', 'MZZONE','REG_FEE'
                , 'QS_ROOMS', 'QS_BATHROOM', 'QS_BEDROOM'],axis='columns')
df2.head()
# Out:
#          AREA  INT_SQFT   DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  Karapakkam      1004  04-05-2011        1.0         1.0       3
# 1  Anna Nagar      1986  19-12-2006        2.0         1.0       5
# 2       Adyar       909  04-02-2012        1.0         1.0       3
# 3   Velachery      1855  13-03-2010        3.0         2.0       5
# 4  Karapakkam      1226  05-10-2009        1.0         1.0       3
#
#    DATE_BUILD   BUILDTYPE  QS_OVERALL  SALES_PRICE
# 0  15-05-1967  Commercial       4.330      7600000
# 1  22-12-1995  Commercial       3.765     21717770
# 2  09-02-1992  Commercial       3.090     13159200
# 3  18-03-1988      Others       4.010      9630290
# 4  13-10-1979      Others       3.290      7406250

# %%
df2.shape
# Out:
# (7109, 10)

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# AREA           0
# INT_SQFT       0
# DATE_SALE      0
# N_BEDROOM      0
# N_BATHROOM     0
# N_ROOM         0
# DATE_BUILD     0
# BUILDTYPE      0
# QS_OVERALL     0
# SALES_PRICE    0
# dtype: int64

# %%
df3.head()
# Out:
#          AREA  INT_SQFT   DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  Karapakkam      1004  04-05-2011        1.0         1.0       3
# 1  Anna Nagar      1986  19-12-2006        2.0         1.0       5
# 2       Adyar       909  04-02-2012        1.0         1.0       3
# 3   Velachery      1855  13-03-2010        3.0         2.0       5
# 4  Karapakkam      1226  05-10-2009        1.0         1.0       3
#
#    DATE_BUILD   BUILDTYPE  QS_OVERALL  SALES_PRICE
# 0  15-05-1967  Commercial       4.330      7600000
# 1  22-12-1995  Commercial       3.765     21717770
# 2  09-02-1992  Commercial       3.090     13159200
# 3  18-03-1988      Others       4.010      9630290
# 4  13-10-1979      Others       3.290      7406250

# %% [markdown]
# Feature Engineering

# %%
type(df3['DATE_SALE'][0])
# Out:
# str

# %%
#defining a function to calculate age of property
def calculate_age_build(df, date_sale_col, date_build_col):
    df = df.copy()
    # Convert date columns to datetime 
    df[date_sale_col] = pd.to_datetime(df[date_sale_col], format='%d-%m-%Y')
    df[date_build_col] = pd.to_datetime(df[date_build_col], format='%d-%m-%Y')
    df['AGE_BUILD'] = (df[date_sale_col] - df[date_build_col]).dt.days // 365
    
    return df

# %%
df4 = calculate_age_build(df3, 'DATE_SALE', 'DATE_BUILD')
df4.head()
# Out:
#          AREA  INT_SQFT  DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM DATE_BUILD  \
# 0  Karapakkam      1004 2011-05-04        1.0         1.0       3 1967-05-15
# 1  Anna Nagar      1986 2006-12-19        2.0         1.0       5 1995-12-22
# 2       Adyar       909 2012-02-04        1.0         1.0       3 1992-02-09
# 3   Velachery      1855 2010-03-13        3.0         2.0       5 1988-03-18
# 4  Karapakkam      1226 2009-10-05        1.0         1.0       3 1979-10-13
#
#     BUILDTYPE  QS_OVERALL  SALES_PRICE  AGE_BUILD
# 0  Commercial       4.330      7600000         44
# 1  Commercial       3.765     21717770         11
# 2  Commercial       3.090     13159200         20
# 3      Others       4.010      9630290         22
# 4      Others       3.290      7406250         30

# %%
df4['N_BEDROOM'].unique()
# Out:
# array([1., 2., 3., 4.])

# %%
df4['AGE_BUILD'].unique()
# Out:
# array([44, 11, 20, 22, 30,  5, 28, 10, 34, 15, 37, 19, 26, 54, 18, 42,  4,
#        16,  7, 39, 35,  9,  6, 21, 27, 13, 40, 36, 48, 46, 29, 49, 45, 31,
#        41, 24, 25, 23, 33, 43,  8, 17, 14, 32, 53, 38, 12, 50, 55, 47, 51,
#        52])

# %%
df4['N_BATHROOM'].unique()
# Out:
# array([1., 2.])

# %%
df4['N_ROOM'].unique()
# Out:
# array([3, 5, 4, 2, 6])

# %%
df5 = df4.drop(['DATE_SALE' , 'DATE_BUILD'],axis = 'columns')
df5.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD
# 0       4.330      7600000         44
# 1       3.765     21717770         11
# 2       3.090     13159200         20
# 3       4.010      9630290         22
# 4       3.290      7406250         30

# %%
df5['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'TNagar', 'T Nagar', 'Chrompt', 'Chrmpet', 'Karapakam',
#        'Ana Nagar', 'Chormpet', 'Adyr', 'Velchery', 'Ann Nagar',
#        'KKNagar'], dtype=object)

# %%
df5['AREA'] = df5['AREA'].replace(
    ['TNagar', 'Chrompt', 'Chrmpet', 'Karapakam', 'Ana Nagar', 'Chormpet', 
     'Adyr', 'Velchery', 'Ann Nagar', 'KKNagar'],
    ['T Nagar', 'Chrompet', 'Chrompet', 'Karapakkam', 'Anna Nagar', 'Chrompet', 
     'Adyar', 'Velachery', 'Anna Nagar', 'KK Nagar']
)

# %%
df5['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'T Nagar'], dtype=object)

# %%
df5.head(10)
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
# 5    Chrompet      1220        2.0         1.0       4  Commercial
# 6    Chrompet      1167        1.0         1.0       3       Other
# 7   Velachery      1847        3.0         2.0       5  Commercial
# 8    Chrompet       771        1.0         1.0       2      Others
# 9   Velachery      1635        2.0         1.0       4      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD
# 0       4.330      7600000         44
# 1       3.765     21717770         11
# 2       3.090     13159200         20
# 3       4.010      9630290         22
# 4       3.290      7406250         30
# 5       3.320     12394750          5
# 6       2.670      8488790         28
# 7       3.260     16800250         10
# 8       3.550      8308970         34
# 9       3.160      8083650         15

# %%
df5['INT_SQFT'].unique()
# Out:
# array([1004, 1986,  909, ...,  688, 2051,  598], shape=(1698,))

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df5['INT_SQFT'], df5['N_ROOM'], color='blue')
plt.title('INT_SQFT vs N_ROOM', fontsize=14)
plt.xlabel('INT_SQFT (Square Feet)', fontsize=12)
plt.ylabel('N_ROOM (Number of Rooms)', fontsize=12)
plt.show()

# %%
df5 = df5[~((df5['INT_SQFT'] >= 2000) & (df5['INT_SQFT'] <= 2100) & (df5['N_ROOM'] == 6))]
df5.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD
# 0       4.330      7600000         44
# 1       3.765     21717770         11
# 2       3.090     13159200         20
# 3       4.010      9630290         22
# 4       3.290      7406250         30

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df5['INT_SQFT'], df5['N_ROOM'], color='blue')
plt.title('INT_SQFT vs N_ROOM', fontsize=14)
plt.xlabel('INT_SQFT (Square Feet)', fontsize=12)
plt.ylabel('N_ROOM (Number of Rooms)', fontsize=12)
plt.show()

# %%
df5['AGE_BUILD'].unique()
# Out:
# array([44, 11, 20, 22, 30,  5, 28, 10, 34, 15, 37, 19, 26, 54, 18, 42,  4,
#        16,  7, 39, 35,  9,  6, 21, 27, 13, 40, 36, 48, 46, 29, 49, 45, 31,
#        41, 24, 25, 23, 33, 43,  8, 17, 14, 32, 53, 38, 12, 50, 55, 47, 51,
#        52])

# %%
df5['AREA'].unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'T Nagar'], dtype=object)

# %%
df5.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD
# 0       4.330      7600000         44
# 1       3.765     21717770         11
# 2       3.090     13159200         20
# 3       4.010      9630290         22
# 4       3.290      7406250         30

# %%
df5['BUILDTYPE'].value_counts()
# Out:
# BUILDTYPE
# House         2433
# Commercial    2306
# Others        2287
# Other           25
# Comercial        4
# Name: count, dtype: int64

# %%
df5['BUILDTYPE'] = df5['BUILDTYPE'].replace(
    ['Comercial','Other'],
    ['Commercial','Others']
)

# %%
df5['BUILDTYPE'].value_counts()
# Out:
# BUILDTYPE
# House         2433
# Others        2312
# Commercial    2310
# Name: count, dtype: int64

# %%
dummies = pd.get_dummies(df5.AREA)
dummies.head()
# Out:
#    Adyar  Anna Nagar  Chrompet  KK Nagar  Karapakkam  T Nagar  Velachery
# 0  False       False     False     False        True    False      False
# 1  False        True     False     False       False    False      False
# 2   True       False     False     False       False    False      False
# 3  False       False     False     False       False    False       True
# 4  False       False     False     False        True    False      False

# %%
df6 = pd.concat([df5,dummies], axis = 'columns')
df6.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD  Adyar  Anna Nagar  Chrompet  KK Nagar  \
# 0       4.330      7600000         44  False       False     False     False
# 1       3.765     21717770         11  False        True     False     False
# 2       3.090     13159200         20   True       False     False     False
# 3       4.010      9630290         22  False       False     False     False
# 4       3.290      7406250         30  False       False     False     False
#
#    Karapakkam  T Nagar  Velachery
# 0        True    False      False
# 1       False    False      False
# 2       False    False      False
# 3       False    False       True
# 4        True    False      False

# %%
dummies1 = pd.get_dummies(df5.BUILDTYPE)
dummies1.head()
# Out:
#    Commercial  House  Others
# 0        True  False   False
# 1        True  False   False
# 2        True  False   False
# 3       False  False    True
# 4       False  False    True

# %%
df7 = pd.concat([df6,dummies1], axis = 'columns')
df7.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM   BUILDTYPE  \
# 0  Karapakkam      1004        1.0         1.0       3  Commercial
# 1  Anna Nagar      1986        2.0         1.0       5  Commercial
# 2       Adyar       909        1.0         1.0       3  Commercial
# 3   Velachery      1855        3.0         2.0       5      Others
# 4  Karapakkam      1226        1.0         1.0       3      Others
#
#    QS_OVERALL  SALES_PRICE  AGE_BUILD  Adyar  Anna Nagar  Chrompet  KK Nagar  \
# 0       4.330      7600000         44  False       False     False     False
# 1       3.765     21717770         11  False        True     False     False
# 2       3.090     13159200         20   True       False     False     False
# 3       4.010      9630290         22  False       False     False     False
# 4       3.290      7406250         30  False       False     False     False
#
#    Karapakkam  T Nagar  Velachery  Commercial  House  Others
# 0        True    False      False        True  False   False
# 1       False    False      False        True  False   False
# 2       False    False      False        True  False   False
# 3       False    False       True       False  False    True
# 4        True    False      False       False  False    True

# %%
df8 = df7.drop('BUILDTYPE',axis='columns')
df8.head()
# Out:
#          AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  QS_OVERALL  \
# 0  Karapakkam      1004        1.0         1.0       3       4.330
# 1  Anna Nagar      1986        2.0         1.0       5       3.765
# 2       Adyar       909        1.0         1.0       3       3.090
# 3   Velachery      1855        3.0         2.0       5       4.010
# 4  Karapakkam      1226        1.0         1.0       3       3.290
#
#    SALES_PRICE  AGE_BUILD  Adyar  Anna Nagar  Chrompet  KK Nagar  Karapakkam  \
# 0      7600000         44  False       False     False     False        True
# 1     21717770         11  False        True     False     False       False
# 2     13159200         20   True       False     False     False       False
# 3      9630290         22  False       False     False     False       False
# 4      7406250         30  False       False     False     False        True
#
#    T Nagar  Velachery  Commercial  House  Others
# 0    False      False        True  False   False
# 1    False      False        True  False   False
# 2    False      False        True  False   False
# 3    False       True       False  False    True
# 4    False      False       False  False    True

# %%
df9 = df8.drop('AREA',axis='columns')
df9.head()
# Out:
#    INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  QS_OVERALL  SALES_PRICE  \
# 0      1004        1.0         1.0       3       4.330      7600000
# 1      1986        2.0         1.0       5       3.765     21717770
# 2       909        1.0         1.0       3       3.090     13159200
# 3      1855        3.0         2.0       5       4.010      9630290
# 4      1226        1.0         1.0       3       3.290      7406250
#
#    AGE_BUILD  Adyar  Anna Nagar  Chrompet  KK Nagar  Karapakkam  T Nagar  \
# 0         44  False       False     False     False        True    False
# 1         11  False        True     False     False       False    False
# 2         20   True       False     False     False       False    False
# 3         22  False       False     False     False       False    False
# 4         30  False       False     False     False        True    False
#
#    Velachery  Commercial  House  Others
# 0      False        True  False   False
# 1      False        True  False   False
# 2      False        True  False   False
# 3       True       False  False    True
# 4      False       False  False    True

# %%
df9.shape
# Out:
# (7055, 17)

# %%
X = df9.drop('SALES_PRICE',axis='columns')
X.head()
# Out:
#    INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  QS_OVERALL  AGE_BUILD  Adyar  \
# 0      1004        1.0         1.0       3       4.330         44  False
# 1      1986        2.0         1.0       5       3.765         11  False
# 2       909        1.0         1.0       3       3.090         20   True
# 3      1855        3.0         2.0       5       4.010         22  False
# 4      1226        1.0         1.0       3       3.290         30  False
#
#    Anna Nagar  Chrompet  KK Nagar  Karapakkam  T Nagar  Velachery  Commercial  \
# 0       False     False     False        True    False      False        True
# 1        True     False     False       False    False      False        True
# 2       False     False     False       False    False      False        True
# 3       False     False     False       False    False       True       False
# 4       False     False     False        True    False      False       False
#
#    House  Others
# 0  False   False
# 1  False   False
# 2  False   False
# 3  False    True
# 4  False    True

# %%
y = df9.SALES_PRICE
y.head()
# Out:
# 0     7600000
# 1    21717770
# 2    13159200
# 3     9630290
# 4     7406250
# Name: SALES_PRICE, dtype: int64

# %% [markdown]
# Building a linear regression model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test) #calculates r2 score
# Out:
# 0.8760301172989874

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.87911781, 0.88195716, 0.88095247, 0.88190345, 0.87205677])
